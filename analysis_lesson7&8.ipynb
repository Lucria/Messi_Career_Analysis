# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings("ignore")

# %%
# From lesson 2: Importing CSV data, and viewing the first 10 rows
events = pd.read_csv("./data/events.csv")
# events.info()
# events.head(10)

ginf = pd.read_csv("./data/ginf.csv")
# ginf.info()
# ginf.head(10)

# %%
events_data = ginf.merge(events, how="left")
events_data.head(10)
# Out:
#      id_odsp                                          link_odsp  adv_stats  \
# 0  UFot0hit/  /soccer/germany/bundesliga-2011-2012/dortmund-...       True
# 1  UFot0hit/  /soccer/germany/bundesliga-2011-2012/dortmund-...       True
# 2  UFot0hit/  /soccer/germany/bundesliga-2011-2012/dortmund-...       True
# 3  UFot0hit/  /soccer/germany/bundesliga-2011-2012/dortmund-...       True
# 4  UFot0hit/  /soccer/germany/bundesliga-2011-2012/dortmund-...       True
# 5  UFot0hit/  /soccer/germany/bundesliga-2011-2012/dortmund-...       True
# 6  UFot0hit/  /soccer/germany/bundesliga-2011-2012/dortmund-...       True
# 7  UFot0hit/  /soccer/germany/bundesliga-2011-2012/dortmund-...       True
# 8  UFot0hit/  /soccer/germany/bundesliga-2011-2012/dortmund-...       True
# 9  UFot0hit/  /soccer/germany/bundesliga-2011-2012/dortmund-...       True
#
#          date league  season  country                 ht          at  fthg  \
# 0  2011-08-05     D1    2012  germany  Borussia Dortmund  Hamburg SV     3
# 1  2011-08-05     D1    2012  germany  Borussia Dortmund  Hamburg SV     3
# 2  2011-08-05     D1    2012  germany  Borussia Dortmund  Hamburg SV     3
# 3  2011-08-05     D1    2012  germany  Borussia Dortmund  Hamburg SV     3
# 4  2011-08-05     D1    2012  germany  Borussia Dortmund  Hamburg SV     3
# 5  2011-08-05     D1    2012  germany  Borussia Dortmund  Hamburg SV     3
# 6  2011-08-05     D1    2012  germany  Borussia Dortmund  Hamburg SV     3
# 7  2011-08-05     D1    2012  germany  Borussia Dortmund  Hamburg SV     3
# 8  2011-08-05     D1    2012  germany  Borussia Dortmund  Hamburg SV     3
# 9  2011-08-05     D1    2012  germany  Borussia Dortmund  Hamburg SV     3
#
#    ...  player_in  player_out  shot_place  shot_outcome  is_goal  location  \
# 0  ...        NaN         NaN         6.0           2.0      0.0       9.0
# 1  ...        NaN         NaN         NaN           NaN      0.0       NaN
# 2  ...        NaN         NaN         NaN           NaN      0.0       NaN
# 3  ...        NaN         NaN         NaN           NaN      0.0       NaN
# 4  ...        NaN         NaN         NaN           NaN      0.0       2.0
# 5  ...        NaN         NaN         NaN           NaN      0.0       NaN
# 6  ...        NaN         NaN         NaN           NaN      0.0       NaN
# 7  ...        NaN         NaN         NaN           NaN      0.0       2.0
# 8  ...        NaN         NaN         NaN           NaN      0.0       NaN
# 9  ...        NaN         NaN         NaN           NaN      0.0       NaN
#
#    bodypart  assist_method situation  fast_break
# 0       2.0            1.0       1.0         0.0
# 1       NaN            0.0       NaN         0.0
# 2       NaN            0.0       NaN         0.0
# 3       NaN            0.0       NaN         0.0
# 4       NaN            0.0       NaN         0.0
# 5       NaN            0.0       NaN         0.0
# 6       NaN            0.0       NaN         0.0
# 7       NaN            0.0       NaN         0.0
# 8       NaN            0.0       NaN         0.0
# 9       NaN            0.0       NaN         0.0
#
# [10 rows x 39 columns]

# %%
f = open("./data/dictionary.txt")
data = f.read()
print(data)
# Out:
# event_type
# 0	Announcement
# 1	Attempt
# 2	Corner
# 3	Foul
# 4	Yellow card
# 5	Second yellow card
# 6	Red card
# 7	Substitution
# 8	Free kick won
# 9	Offside
# 10	Hand ball
# 11	Penalty conceded
#
#
# event_type2
# 12	Key Pass
# 13	Failed through ball
# 14	Sending off
# 15	Own goal
#
#
# side
# 1	Home
# 2	Away
#
#
# shot_place
# 1	Bit too high
# 2	Blocked
# 3	Bottom left corner
# 4	Bottom right corner
# 5	Centre of the goal
# 6	High and wide
# 7	Hits the bar
# 8	Misses to the left
# 9	Misses to the right
# 10	Too high
# 11	Top centre of the goal
# 12	Top left corner
# 13	Top right corner
#
#
# shot_outcome
# 1	On target
# 2	Off target
# 3	Blocked
# 4	Hit the bar
#
#
# location
# 1	Attacking half
# 2	Defensive half
# 3	Centre of the box
# 4	Left wing
# 5	Right wing
# 6	Difficult angle and long range
# 7	Difficult angle on the left
# 8	Difficult angle on the right
# 9	Left side of the box
# 10	Left side of the six yard box
# 11	Right side of the box
# 12	Right side of the six yard box
# 13	Very close range
# 14	Penalty spot
# 15	Outside the box
# 16	Long range
# 17	More than 35 yards
# 18	More than 40 yards
# 19	Not recorded
#
#
# bodypart
# 1	right foot
# 2	left foot
# 3	head
#
#
# assist_method
# 0	None
# 1	Pass
# 2	Cross
# 3	Headed pass
# 4	Through ball
#
#
# situation
# 1	Open play
# 2	Set piece
# 3	Corner
# 4	Free kick

# %%
# Separate the different types of information
data = data.split("\n\n\n")
print(data)
# Out:
# ['event_type\n0\tAnnouncement\n1\tAttempt\n2\tCorner\n3\tFoul\n4\tYellow card\n5\tSecond yellow card\n6\tRed card\n7\tSubstitution\n8\tFree kick won\n9\tOffside\n10\tHand ball\n11\tPenalty conceded', 'event_type2\n12\tKey Pass\n13\tFailed through ball\n14\tSending off\n15\tOwn goal', 'side\n1\tHome\n2\tAway', 'shot_place\n1\tBit too high\n2\tBlocked\n3\tBottom left corner\n4\tBottom right corner\n5\tCentre of the goal\n6\tHigh and wide\n7\tHits the bar\n8\tMisses to the left\n9\tMisses to the right\n10\tToo high\n11\tTop centre of the goal\n12\tTop left corner\n13\tTop right corner', 'shot_outcome\n1\tOn target\n2\tOff target\n3\tBlocked\n4\tHit the bar', 'location\n1\tAttacking half\n2\tDefensive half\n3\tCentre of the box\n4\tLeft wing\n5\tRight wing\n6\tDifficult angle and long range\n7\tDifficult angle on the left\n8\tDifficult angle on the right\n9\tLeft side of the box\n10\tLeft side of the six yard box\n11\tRight side of the box\n12\tRight side of the six yard box\n13\tVery close range\n14\tPenalty spot\n15\tOutside the box\n16\tLong range\n17\tMore than 35 yards\n18\tMore than 40 yards\n19\tNot recorded', 'bodypart\n1\tright foot\n2\tleft foot\n3\thead', 'assist_method\n0\tNone\n1\tPass\n2\tCross\n3\tHeaded pass\n4\tThrough ball', 'situation\n1\tOpen play\n2\tSet piece\n3\tCorner\n4\tFree kick', '', '', '', '', '', '']

# %%
print(data)
# Out:
# ['event_type\n0\tAnnouncement\n1\tAttempt\n2\tCorner\n3\tFoul\n4\tYellow card\n5\tSecond yellow card\n6\tRed card\n7\tSubstitution\n8\tFree kick won\n9\tOffside\n10\tHand ball\n11\tPenalty conceded', 'event_type2\n12\tKey Pass\n13\tFailed through ball\n14\tSending off\n15\tOwn goal', 'side\n1\tHome\n2\tAway', 'shot_place\n1\tBit too high\n2\tBlocked\n3\tBottom left corner\n4\tBottom right corner\n5\tCentre of the goal\n6\tHigh and wide\n7\tHits the bar\n8\tMisses to the left\n9\tMisses to the right\n10\tToo high\n11\tTop centre of the goal\n12\tTop left corner\n13\tTop right corner', 'shot_outcome\n1\tOn target\n2\tOff target\n3\tBlocked\n4\tHit the bar', 'location\n1\tAttacking half\n2\tDefensive half\n3\tCentre of the box\n4\tLeft wing\n5\tRight wing\n6\tDifficult angle and long range\n7\tDifficult angle on the left\n8\tDifficult angle on the right\n9\tLeft side of the box\n10\tLeft side of the six yard box\n11\tRight side of the box\n12\tRight side of the six yard box\n13\tVery close range\n14\tPenalty spot\n15\tOutside the box\n16\tLong range\n17\tMore than 35 yards\n18\tMore than 40 yards\n19\tNot recorded', 'bodypart\n1\tright foot\n2\tleft foot\n3\thead', 'assist_method\n0\tNone\n1\tPass\n2\tCross\n3\tHeaded pass\n4\tThrough ball', 'situation\n1\tOpen play\n2\tSet piece\n3\tCorner\n4\tFree kick', '', '', '', '', '', '']

# %%
f = open("./data/dictionary.txt")
data = f.read()
data_list = data.split("\n\n\n")
print(data_list)
# Out:
# ['event_type\n0\tAnnouncement\n1\tAttempt\n2\tCorner\n3\tFoul\n4\tYellow card\n5\tSecond yellow card\n6\tRed card\n7\tSubstitution\n8\tFree kick won\n9\tOffside\n10\tHand ball\n11\tPenalty conceded', 'event_type2\n12\tKey Pass\n13\tFailed through ball\n14\tSending off\n15\tOwn goal', 'side\n1\tHome\n2\tAway', 'shot_place\n1\tBit too high\n2\tBlocked\n3\tBottom left corner\n4\tBottom right corner\n5\tCentre of the goal\n6\tHigh and wide\n7\tHits the bar\n8\tMisses to the left\n9\tMisses to the right\n10\tToo high\n11\tTop centre of the goal\n12\tTop left corner\n13\tTop right corner', 'shot_outcome\n1\tOn target\n2\tOff target\n3\tBlocked\n4\tHit the bar', 'location\n1\tAttacking half\n2\tDefensive half\n3\tCentre of the box\n4\tLeft wing\n5\tRight wing\n6\tDifficult angle and long range\n7\tDifficult angle on the left\n8\tDifficult angle on the right\n9\tLeft side of the box\n10\tLeft side of the six yard box\n11\tRight side of the box\n12\tRight side of the six yard box\n13\tVery close range\n14\tPenalty spot\n15\tOutside the box\n16\tLong range\n17\tMore than 35 yards\n18\tMore than 40 yards\n19\tNot recorded', 'bodypart\n1\tright foot\n2\tleft foot\n3\thead', 'assist_method\n0\tNone\n1\tPass\n2\tCross\n3\tHeaded pass\n4\tThrough ball', 'situation\n1\tOpen play\n2\tSet piece\n3\tCorner\n4\tFree kick', '', '', '', '', '', '']

# %%
new = dict() # title as key, dictionary as value

for adwaita in data_list:

    # Ignore empty values
    if not adwaita:
        break

    adwaita_list = adwaita.split("\n")
    title = adwaita_list[0] # Key for top dictionary
    values = adwaita_list[1:]

    # Split and save values in a dictionary
    temp_dict = dict() # integer as key, string as value
    # Go through each element of values
    for value in values:
        # Separate number and word that is separated by \t
        jerry = value.split("\t")
        number = int(jerry[0])
        text = jerry[1]
        # Save things to dictionary ([key] = value)
        temp_dict[number] = text

    new[title] = temp_dict

print(new)
# Out:
# {'event_type': {0: 'Announcement', 1: 'Attempt', 2: 'Corner', 3: 'Foul', 4: 'Yellow card', 5: 'Second yellow card', 6: 'Red card', 7: 'Substitution', 8: 'Free kick won', 9: 'Offside', 10: 'Hand ball', 11: 'Penalty conceded'}, 'event_type2': {12: 'Key Pass', 13: 'Failed through ball', 14: 'Sending off', 15: 'Own goal'}, 'side': {1: 'Home', 2: 'Away'}, 'shot_place': {1: 'Bit too high', 2: 'Blocked', 3: 'Bottom left corner', 4: 'Bottom right corner', 5: 'Centre of the goal', 6: 'High and wide', 7: 'Hits the bar', 8: 'Misses to the left', 9: 'Misses to the right', 10: 'Too high', 11: 'Top centre of the goal', 12: 'Top left corner', 13: 'Top right corner'}, 'shot_outcome': {1: 'On target', 2: 'Off target', 3: 'Blocked', 4: 'Hit the bar'}, 'location': {1: 'Attacking half', 2: 'Defensive half', 3: 'Centre of the box', 4: 'Left wing', 5: 'Right wing', 6: 'Difficult angle and long range', 7: 'Difficult angle on the left', 8: 'Difficult angle on the right', 9: 'Left side of the box', 10: 'Left side of the six yard box', 11: 'Right side of the box', 12: 'Right side of the six yard box', 13: 'Very close range', 14: 'Penalty spot', 15: 'Outside the box', 16: 'Long range', 17: 'More than 35 yards', 18: 'More than 40 yards', 19: 'Not recorded'}, 'bodypart': {1: 'right foot', 2: 'left foot', 3: 'head'}, 'assist_method': {0: 'None', 1: 'Pass', 2: 'Cross', 3: 'Headed pass', 4: 'Through ball'}, 'situation': {1: 'Open play', 2: 'Set piece', 3: 'Corner', 4: 'Free kick'}}

# %%
for name in new:
    events_data[name] = events_data[name].map(new[name])

events_data.head(10)
# Out:
#      id_odsp                                          link_odsp  adv_stats  \
# 0  UFot0hit/  /soccer/germany/bundesliga-2011-2012/dortmund-...       True
# 1  UFot0hit/  /soccer/germany/bundesliga-2011-2012/dortmund-...       True
# 2  UFot0hit/  /soccer/germany/bundesliga-2011-2012/dortmund-...       True
# 3  UFot0hit/  /soccer/germany/bundesliga-2011-2012/dortmund-...       True
# 4  UFot0hit/  /soccer/germany/bundesliga-2011-2012/dortmund-...       True
# 5  UFot0hit/  /soccer/germany/bundesliga-2011-2012/dortmund-...       True
# 6  UFot0hit/  /soccer/germany/bundesliga-2011-2012/dortmund-...       True
# 7  UFot0hit/  /soccer/germany/bundesliga-2011-2012/dortmund-...       True
# 8  UFot0hit/  /soccer/germany/bundesliga-2011-2012/dortmund-...       True
# 9  UFot0hit/  /soccer/germany/bundesliga-2011-2012/dortmund-...       True
#
#          date league  season  country                 ht          at  fthg  \
# 0  2011-08-05     D1    2012  germany  Borussia Dortmund  Hamburg SV     3
# 1  2011-08-05     D1    2012  germany  Borussia Dortmund  Hamburg SV     3
# 2  2011-08-05     D1    2012  germany  Borussia Dortmund  Hamburg SV     3
# 3  2011-08-05     D1    2012  germany  Borussia Dortmund  Hamburg SV     3
# 4  2011-08-05     D1    2012  germany  Borussia Dortmund  Hamburg SV     3
# 5  2011-08-05     D1    2012  germany  Borussia Dortmund  Hamburg SV     3
# 6  2011-08-05     D1    2012  germany  Borussia Dortmund  Hamburg SV     3
# 7  2011-08-05     D1    2012  germany  Borussia Dortmund  Hamburg SV     3
# 8  2011-08-05     D1    2012  germany  Borussia Dortmund  Hamburg SV     3
# 9  2011-08-05     D1    2012  germany  Borussia Dortmund  Hamburg SV     3
#
#    ...  player_in  player_out     shot_place  shot_outcome  is_goal  \
# 0  ...        NaN         NaN  High and wide    Off target      0.0
# 1  ...        NaN         NaN            NaN           NaN      0.0
# 2  ...        NaN         NaN            NaN           NaN      0.0
# 3  ...        NaN         NaN            NaN           NaN      0.0
# 4  ...        NaN         NaN            NaN           NaN      0.0
# 5  ...        NaN         NaN            NaN           NaN      0.0
# 6  ...        NaN         NaN            NaN           NaN      0.0
# 7  ...        NaN         NaN            NaN           NaN      0.0
# 8  ...        NaN         NaN            NaN           NaN      0.0
# 9  ...        NaN         NaN            NaN           NaN      0.0
#
#                location   bodypart  assist_method  situation  fast_break
# 0  Left side of the box  left foot           Pass  Open play         0.0
# 1                   NaN        NaN           None        NaN         0.0
# 2                   NaN        NaN           None        NaN         0.0
# 3                   NaN        NaN           None        NaN         0.0
# 4        Defensive half        NaN           None        NaN         0.0
# 5                   NaN        NaN           None        NaN         0.0
# 6                   NaN        NaN           None        NaN         0.0
# 7        Defensive half        NaN           None        NaN         0.0
# 8                   NaN        NaN           None        NaN         0.0
# 9                   NaN        NaN           None        NaN         0.0
#
# [10 rows x 39 columns]

# %%
lionel_messi_events = events_data.loc[events_data["player"] == "lionel messi"]
lionel_messi_events.head(5)
# Out:
#         id_odsp                                          link_odsp  adv_stats  \
# 9142  2mfCxQlt/  /soccer/spain/primera-division-2011-2012/barce...       True
# 9147  2mfCxQlt/  /soccer/spain/primera-division-2011-2012/barce...       True
# 9151  2mfCxQlt/  /soccer/spain/primera-division-2011-2012/barce...       True
# 9155  2mfCxQlt/  /soccer/spain/primera-division-2011-2012/barce...       True
# 9164  2mfCxQlt/  /soccer/spain/primera-division-2011-2012/barce...       True
#
#             date league  season country         ht          at  fthg  ...  \
# 9142  2011-08-29    SP1    2012   spain  Barcelona  Villarreal     5  ...
# 9147  2011-08-29    SP1    2012   spain  Barcelona  Villarreal     5  ...
# 9151  2011-08-29    SP1    2012   spain  Barcelona  Villarreal     5  ...
# 9155  2011-08-29    SP1    2012   spain  Barcelona  Villarreal     5  ...
# 9164  2011-08-29    SP1    2012   spain  Barcelona  Villarreal     5  ...
#
#       player_in  player_out           shot_place  shot_outcome  is_goal  \
# 9142        NaN         NaN                  NaN           NaN      0.0
# 9147        NaN         NaN   Bottom left corner     On target      0.0
# 9151        NaN         NaN  Bottom right corner     On target      0.0
# 9155        NaN         NaN                  NaN           NaN      0.0
# 9164        NaN         NaN                  NaN           NaN      0.0
#
#                          location   bodypart  assist_method  situation  \
# 9142                          NaN        NaN           None        NaN
# 9147  Difficult angle on the left  left foot           Pass  Open play
# 9151              Outside the box  left foot           None  Open play
# 9155               Attacking half        NaN           None        NaN
# 9164               Attacking half        NaN           None        NaN
#
#       fast_break
# 9142         0.0
# 9147         0.0
# 9151         0.0
# 9155         0.0
# 9164         0.0
#
# [5 rows x 39 columns]

# %%
lionel_messi_goals = lionel_messi_events.loc[events_data["is_goal"] == 1]
lionel_messi_goals.head(10)
# Out:
#          id_odsp                                          link_odsp  \
# 9192   2mfCxQlt/  /soccer/spain/primera-division-2011-2012/barce...
# 9212   2mfCxQlt/  /soccer/spain/primera-division-2011-2012/barce...
# 14172  j9jGN56j/  /soccer/spain/primera-division-2011-2012/barce...
# 14209  j9jGN56j/  /soccer/spain/primera-division-2011-2012/barce...
# 14257  j9jGN56j/  /soccer/spain/primera-division-2011-2012/barce...
# 22018  vTglm2Ke/  /soccer/spain/primera-division-2011-2012/barce...
# 22086  vTglm2Ke/  /soccer/spain/primera-division-2011-2012/barce...
# 22100  vTglm2Ke/  /soccer/spain/primera-division-2011-2012/barce...
# 28940  8I6s1CfC/  /soccer/spain/primera-division-2011-2012/barce...
# 28993  8I6s1CfC/  /soccer/spain/primera-division-2011-2012/barce...
#
#        adv_stats        date league  season country         ht  \
# 9192        True  2011-08-29    SP1    2012   spain  Barcelona
# 9212        True  2011-08-29    SP1    2012   spain  Barcelona
# 14172       True  2011-09-17    SP1    2012   spain  Barcelona
# 14209       True  2011-09-17    SP1    2012   spain  Barcelona
# 14257       True  2011-09-17    SP1    2012   spain  Barcelona
# 22018       True  2011-09-24    SP1    2012   spain  Barcelona
# 22086       True  2011-09-24    SP1    2012   spain  Barcelona
# 22100       True  2011-09-24    SP1    2012   spain  Barcelona
# 28940       True  2011-10-15    SP1    2012   spain  Barcelona
# 28993       True  2011-10-15    SP1    2012   spain  Barcelona
#
#                      at  fthg  ...  player_in  player_out  \
# 9192         Villarreal     5  ...        NaN         NaN
# 9212         Villarreal     5  ...        NaN         NaN
# 14172           Osasuna     8  ...        NaN         NaN
# 14209           Osasuna     8  ...        NaN         NaN
# 14257           Osasuna     8  ...        NaN         NaN
# 22018   Atletico Madrid     5  ...        NaN         NaN
# 22086   Atletico Madrid     5  ...        NaN         NaN
# 22100   Atletico Madrid     5  ...        NaN         NaN
# 28940  Racing Santander     3  ...        NaN         NaN
# 28993  Racing Santander     3  ...        NaN         NaN
#
#                 shot_place  shot_outcome  is_goal  \
# 9192   Bottom right corner     On target      1.0
# 9212    Centre of the goal     On target      1.0
# 14172  Bottom right corner     On target      1.0
# 14209  Bottom right corner     On target      1.0
# 14257   Centre of the goal     On target      1.0
# 22018  Bottom right corner     On target      1.0
# 22086  Bottom right corner     On target      1.0
# 22100   Centre of the goal     On target      1.0
# 28940   Bottom left corner     On target      1.0
# 28993  Bottom right corner     On target      1.0
#
#                              location    bodypart  assist_method  situation  \
# 9192   Right side of the six yard box  right foot   Through ball  Open play
# 9212                 Very close range   left foot           Pass  Open play
# 14172                Very close range   left foot    Headed pass  Open play
# 14209               Centre of the box   left foot           Pass  Open play
# 14257               Centre of the box   left foot           Pass  Open play
# 22018           Right side of the box   left foot           Pass  Open play
# 22086               Centre of the box   left foot           None  Open play
# 22100     Difficult angle on the left   left foot   Through ball  Open play
# 28940  Right side of the six yard box  right foot           Pass  Open play
# 28993               Centre of the box  right foot           None  Open play
#
#        fast_break
# 9192          0.0
# 9212          0.0
# 14172         0.0
# 14209         0.0
# 14257         0.0
# 22018         0.0
# 22086         1.0
# 22100         0.0
# 28940         0.0
# 28993         0.0
#
# [10 rows x 39 columns]

# %%
lionel_messi_matches_per_season = lionel_messi_goals.groupby("season")
lionel_messi_matches_per_season.count()
# lionel_messi_matches_per_season.sum()
# lionel_messi_matches_per_season.mean()
# Out:
#         id_odsp  link_odsp  adv_stats  date  league  country  ht  at  fthg  \
# season
# 2012         50         50         50    50      50       50  50  50    50
# 2013         46         46         46    46      46       46  46  46    46
# 2014         28         28         28    28      28       28  28  28    28
# 2015         40         40         40    40      40       40  40  40    40
# 2016         26         26         26    26      26       26  26  26    26
# 2017         15         15         15    15      15       15  15  15    15
#
#         ftag  ...  player_in  player_out  shot_place  shot_outcome  is_goal  \
# season        ...
# 2012      50  ...          0           0          49            50       50
# 2013      46  ...          0           0          44            46       46
# 2014      28  ...          0           0          27            28       28
# 2015      40  ...          0           0          40            40       40
# 2016      26  ...          0           0          25            26       26
# 2017      15  ...          0           0          15            15       15
#
#         location  bodypart  assist_method  situation  fast_break
# season
# 2012          50        50             50         50          50
# 2013          46        46             46         46          46
# 2014          28        28             28         28          28
# 2015          40        40             40         40          40
# 2016          26        26             26         26          26
# 2017          15        15             15         15          15
#
# [6 rows x 38 columns]

# %%
lionel_messi_matches_per_season_goals = lionel_messi_matches_per_season.count().reset_index()
lionel_messi_matches_per_season_goals
# Out:
#    season  id_odsp  link_odsp  adv_stats  date  league  country  ht  at  fthg  \
# 0    2012       50         50         50    50      50       50  50  50    50
# 1    2013       46         46         46    46      46       46  46  46    46
# 2    2014       28         28         28    28      28       28  28  28    28
# 3    2015       40         40         40    40      40       40  40  40    40
# 4    2016       26         26         26    26      26       26  26  26    26
# 5    2017       15         15         15    15      15       15  15  15    15
#
#    ...  player_in  player_out  shot_place  shot_outcome  is_goal  location  \
# 0  ...          0           0          49            50       50        50
# 1  ...          0           0          44            46       46        46
# 2  ...          0           0          27            28       28        28
# 3  ...          0           0          40            40       40        40
# 4  ...          0           0          25            26       26        26
# 5  ...          0           0          15            15       15        15
#
#    bodypart  assist_method  situation  fast_break
# 0        50             50         50          50
# 1        46             46         46          46
# 2        28             28         28          28
# 3        40             40         40          40
# 4        26             26         26          26
# 5        15             15         15          15
#
# [6 rows x 39 columns]

# %%
import matplotlib.pyplot as plt

plt.plot(lionel_messi_matches_per_season_goals["season"], lionel_messi_matches_per_season_goals["is_goal"])
plt.xlabel("Season")
plt.ylabel("Number of Goals")
plt.title("Season to Goals")
plt.show()

# %%
goals_from_assists = lionel_messi_goals.loc[lionel_messi_goals["assist_method"] != None]

lionel_messi_goals_from_assists = goals_from_assists.groupby("player2").count().reset_index()
lionel_messi_goals_from_assists
# Out:
#               player2  id_odsp  link_odsp  adv_stats  date  league  season  \
# 0             adriano        5          5          5     5       5       5
# 1      alexis sanchez       10         10         10    10      10      10
# 2      andres iniesta       13         13         13    13      13      13
# 3          arda turan        3          3          3     3       3       3
# 4       cesc fabregas       10         10         10    10      10      10
# 5      cristian tello        3          3          3     3       3       3
# 6          dani alves       12         12         12    12      12      12
# 7         david villa        4          4          4     4       4       4
# 8   francesc fabregas        1          1          1     1       1       1
# 9        gerard pique        1          1          1     1       1       1
# 10       ivan rakitic        4          4          4     4       4       4
# 11         jordi alba        5          5          5     5       5       5
# 12        luis suarez       15         15         15    15      15      15
# 13        marc bartra        4          4          4     4       4       4
# 14     martin montoya        3          3          3     3       3       3
# 15   munir el haddadi        1          1          1     1       1       1
# 16             neymar       12         12         12    12      12      12
# 17              pedro       12         12         12    12      12      12
# 18            rafinha        1          1          1     1       1       1
# 19      sergi roberto        1          1          1     1       1       1
# 20    sergio busquets        5          5          5     5       5       5
# 21   thiago alcantara        4          4          4     4       4       4
# 22               xavi        5          5          5     5       5       5
#
#     country  ht  at  ...  player_in  player_out  shot_place  shot_outcome  \
# 0         5   5   5  ...          0           0           5             5
# 1        10  10  10  ...          0           0          10            10
# 2        13  13  13  ...          0           0          13            13
# 3         3   3   3  ...          0           0           3             3
# 4        10  10  10  ...          0           0          10            10
# 5         3   3   3  ...          0           0           3             3
# 6        12  12  12  ...          0           0          11            12
# 7         4   4   4  ...          0           0           4             4
# 8         1   1   1  ...          0           0           1             1
# 9         1   1   1  ...          0           0           1             1
# 10        4   4   4  ...          0           0           4             4
# 11        5   5   5  ...          0           0           5             5
# 12       15  15  15  ...          0           0          15            15
# 13        4   4   4  ...          0           0           4             4
# 14        3   3   3  ...          0           0           3             3
# 15        1   1   1  ...          0           0           1             1
# 16       12  12  12  ...          0           0          11            12
# 17       12  12  12  ...          0           0          12            12
# 18        1   1   1  ...          0           0           1             1
# 19        1   1   1  ...          0           0           1             1
# 20        5   5   5  ...          0           0           5             5
# 21        4   4   4  ...          0           0           4             4
# 22        5   5   5  ...          0           0           4             5
#
#     is_goal  location  bodypart  assist_method  situation  fast_break
# 0         5         5         5              5          5           5
# 1        10        10        10             10         10          10
# 2        13        13        13             13         13          13
# 3         3         3         3              3          3           3
# 4        10        10        10             10         10          10
# 5         3         3         3              3          3           3
# 6        12        12        12             12         12          12
# 7         4         4         4              4          4           4
# 8         1         1         1              1          1           1
# 9         1         1         1              1          1           1
# 10        4         4         4              4          4           4
# 11        5         5         5              5          5           5
# 12       15        15        15             15         15          15
# 13        4         4         4              4          4           4
# 14        3         3         3              3          3           3
# 15        1         1         1              1          1           1
# 16       12        12        12             12         12          12
# 17       12        12        12             12         12          12
# 18        1         1         1              1          1           1
# 19        1         1         1              1          1           1
# 20        5         5         5              5          5           5
# 21        4         4         4              4          4           4
# 22        5         5         5              5          5           5
#
# [23 rows x 39 columns]

# %%
# plt.plot(lionel_messi_matches_per_season_goals["season"], lionel_messi_matches_per_season_goals["is_goal"])

plt.figure(figsize=(40, 20))
plt.bar(lionel_messi_goals_from_assists["player2"], lionel_messi_goals_from_assists["assist_method"])
plt.title("Assisters of Lionel Messi Goals")
plt.xlabel("Player")
plt.ylabel("Assist")
plt.show()

# %%
# Sort the number of assists before plotting
lionel_messi_goals_from_assists_sorted = goals_from_assists.groupby("player2").count().sort_values(by=['id_odsp'], ascending=False).reset_index()

plt.figure(figsize=(40, 20))
plt.bar(lionel_messi_goals_from_assists_sorted["player2"], lionel_messi_goals_from_assists_sorted["assist_method"])
plt.title("Assisters of Lionel Messi Goals")
plt.xlabel("Player")
plt.ylabel("Assist")
plt.show()

# %%
# Misc learning

df_test = pd.DataFrame({'Animal': ['Falcon', 'Falcon', 'Eagle', 'Eagle', 'Parrot', 'Parrot'],
                   'Max Speed': [380., 370., 150, 120, 24., 26.]})

df_test.groupby(["Animal"]).mean()
# Out:
#         Max Speed
# Animal
# Eagle       135.0
# Falcon      375.0
# Parrot       25.0

# %%
if 3 == 1:
    print("a")
elif 3 == 2:
    print("b")
else:
    print('c')
# Out:
# 0

# %%
# Fizzbuzz problem
# https://leetcode.com/problems/fizz-buzz/
# Given an integer n, return a string array answer where:
#   answer[i] = "FizzBuzz" if i is divisible by 3 and 5
#   answer[i] = "Fizz" if i is divisible by 3
#   answer[i] = "Buzz" if i is divisible by 5
#   answer[i] = i if none of the above are true

# TODO change print to string array
def fizzBuzz(n):
    for number in range(1, n+1):
        if number % 15 == 0:
            print("FizzBuzz")
        # Check if number is divisible by 3
        elif number % 3 == 0:
            print("Fizz")
        # Check if number is divisible by 5
        elif number % 5 == 0:
            print("Buzz")
        else:
            print(number)
    return


# Below here, I'm running the function with 15 as the input
fizzBuzz(15)
# Out:
# 1
# 2
# Fizz
# 4
# Buzz
# Fizz
# 7
# 8
# Fizz
# Buzz
# 11
# Fizz
# 13
# 14
# fizzbuzz
